# %%
#Session Works
users =["priya","bhoomi","veda","prakruthi"]
admins =["jdoe"]

# %%
def auth_user(name):
  if name in users or name in admins:
    print(f"User {name} is authenticated")
    return True
  return False

# %%
def creat_new(name,role=None):
  if not auth_user(name):
    print( f"User {name} is not allowed to be authenticated")
    raise Exception(f"User {name} is an unauthorised user trying to access the application")
  if name in admins:
    user=input(f"Enter the user")
  else:
    print(f"User {name} is not allowed to create profile")
    raise PermissionError( f"User {name}is an unauthorised user trying to create a profile")

# %%
creat_new ("priya")
# Out:
# User priya is authenticated
# User priya is not allowed to create profile
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-14-0d88d6511d97> in <cell line: 1>()
# ----> 1 creat_new ("priya")
#
# <ipython-input-11-9e63b5ba19a3> in creat_new(name, role)
#       7   else:
#       8     print( f"User {name} is not allowed to create profile")
# ----> 9     raise PermissionError( f"User {name}is an unauthorised user trying to create a profile")
#      10
#      11
#
# PermissionError: User priyais an unauthorised user trying to create a profile
